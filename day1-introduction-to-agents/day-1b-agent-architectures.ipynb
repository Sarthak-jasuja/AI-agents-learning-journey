# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing is poised to revolutionize AI by offering exponential increases in computational power through qubits and superposition, leading to significant speed-ups in tasks like optimization and model training. This synergy, known as Quantum AI, promises to overcome current AI limitations and transform industries such as healthcare, finance, and materials science. While key benefits include accelerated AI model training, improved data processing, and the ability to tackle previously intractable problems, significant challenges remain in hardware stability and scalability. Consequently, widespread commercial adoption is still likely more than a decade away, with hybrid quantum-classical approaches expected to play a crucial role in the near future.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %% [markdown]
# Let's run the agent and give it a topic to write a blog post about:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Catchy Headline:** Beyond Single Threads: How Multi-Agent Systems Can Supercharge Your Software Development
#
# **Introduction Hook:** Are you tired of wrestling with complex, monolithic applications? Do you find yourself bogged down by asynchronous operations and the limitations of single-threaded execution? Imagine a world where your software components can collaborate, learn, and adapt like a well-oiled team. Welcome to the transformative power of multi-agent systems (MAS).
#
# **Main Sections:**
#
# *   **1. Enhanced Problem Solving & Robustness:**
#     *   **Decomposition of Complexity:** Break down intricate problems into smaller, manageable, and independent agents, making development and debugging significantly easier.
#     *   **Resilience Through Redundancy:** If one agent fails, others can often pick up the slack or adapt their behavior, leading to more fault-tolerant and reliable software.
#     *   **Distributed Intelligence:** Leverage the collective knowledge and capabilities of multiple agents to tackle challenges that would be impossible for a single entity.
#
# *   **2. Improved Efficiency & Performance:**
#     *   **Parallel Processing Power:** Distribute tasks across multiple agents that can operate concurrently, dramatically speeding up execution times for computationally intensive operations.
#     *   **Optimized Resource Utilization:** Agents can dynamically manage their resource allocation, ensuring efficient use of CPU, memory, and network bandwidth.
#     *   **Proactive Task Management:** Agents can anticipate needs and initiate tasks before being explicitly prompted, leading to a more responsive and fluid user experience.
#
# *   **3. Increased Adaptability & Learning:**
#     *   **Dynamic System Evolution:** Agents can learn from their environment and interactions, allowing the system to adapt to changing conditions and user behavior without requiring manual code updates.
#     *   **Personalized User Experiences:** Agents can tailor their responses and actions based on individual user preferences and past interactions, creating highly personalized applications.
#     *   **Emergent Behavior:** Complex, intelligent behaviors can arise from the simple interactions of multiple agents, opening doors to novel and innovative functionalities.
#
# *   **4. Streamlined Development & Maintenance:**
#     *   **Modular Design:** MAS naturally promotes modularity, making it easier to add, remove, or update individual agents without disrupting the entire system.
#     *   **Specialized Expertise:** Developers can focus on creating agents with specific functionalities, leading to more specialized and efficient code.
#     *   **Testability & Isolation:** Individual agents can be tested in isolation, simplifying the testing process and improving overall code quality.
#
# **Concluding Thought:** Embracing multi-agent systems is not just about adopting a new paradigm; it's about unlocking a new level of sophistication, resilience, and intelligence in your software. For developers looking to build the next generation of dynamic, efficient, and adaptable applications, the journey into the world of MAS is one well worth embarking on.
# WriterAgent > ## Beyond Single Threads: How Multi-Agent Systems Can Supercharge Your Software Development
#
# Are you tired of wrestling with complex, monolithic applications? Do you find yourself bogged down by asynchronous operations and the limitations of single-threaded execution? Imagine a world where your software components can collaborate, learn, and adapt like a well-oiled team. Welcome to the transformative power of multi-agent systems (MAS).
#
# MAS allows us to break down intricate problems into smaller, manageable, and independent agents. This decomposition significantly eases development and debugging. Crucially, MAS bolsters **robustness** through redundancy; if one agent falters, others can often compensate, leading to more fault-tolerant software. The collective intelligence of multiple agents can tackle challenges that would overwhelm a single entity.
#
# The **efficiency** gains are substantial. MAS unlocks parallel processing power by distributing tasks across concurrent agents, dramatically speeding up execution. Agents can also dynamically manage their resources, ensuring optimal CPU, memory, and network utilization. Furthermore, agents can proactively manage tasks, anticipating needs for a more fluid user experience.
#
# Beyond performance, MAS offers remarkable **adaptability**. Agents can learn from their environment and interactions, allowing systems to evolve without manual code updates. This leads to personalized user experiences as agents tailor actions to individual preferences. You might even witness emergent behavior, where complex, intelligent functionalities arise organically from simple agent interactions.
#
# Finally, MAS streamlines **development and maintenance**. Its inherent modularity makes adding, removing, or updating agents a breeze, without disrupting the entire system. Developers can focus on specialized agent functionalities, and individual agents can be tested in isolation, improving code quality.
#
# Embracing multi-agent systems is about building more sophisticated, resilient, and intelligent software. For developers aiming for the next generation of dynamic applications, the journey into MAS is a powerful one.
# EditorAgent > ## Beyond Single Threads: How Multi-Agent Systems Can Supercharge Your Software Development
#
# Are you tired of wrestling with complex, monolithic applications? Do you find yourself bogged down by asynchronous operations and the limitations of single-threaded execution? Imagine a world where your software components can collaborate, learn, and adapt like a well-oiled team. Welcome to the transformative power of multi-agent systems (MAS).
#
# MAS enables us to break down intricate problems into smaller, manageable, and independent agents. This decomposition significantly eases both development and debugging. Crucially, MAS bolsters **robustness** through redundancy. If one agent falters, others can often compensate, leading to more fault-tolerant software. Moreover, the collective intelligence of multiple agents can tackle challenges that would overwhelm a single entity.
#
# The **efficiency** gains are substantial. MAS unlocks parallel processing power by distributing tasks across concurrent agents, dramatically speeding up execution. Agents can also dynamically manage their resources, ensuring optimal CPU, memory, and network utilization. Furthermore, agents can proactively manage tasks, anticipating needs to create a more fluid user experience.
#
# Beyond performance, MAS offers remarkable **adaptability**. Agents can learn from their environment and interactions, allowing systems to evolve without manual code updates. This leads to personalized user experiences as agents tailor actions to individual preferences. You might even witness emergent behavior, where complex, intelligent functionalities arise organically from simple agent interactions.
#
# Finally, MAS streamlines **development and maintenance**. Its inherent modularity makes adding, removing, or updating agents a breeze, without disrupting the entire system. Developers can focus on specialized agent functionalities, and individual agents can be tested in isolation, improving code quality.
#
# Embracing multi-agent systems is about building more sophisticated, resilient, and intelligent software. For developers aiming for the next generation of dynamic applications, the journey into MAS is a powerful and rewarding one.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > **Health:** Gene therapy is revolutionizing treatment for inherited diseases like sickle cell anemia and blindness. Within the next 1-3 years, expect wider clinical applications of CAR T-cell therapy for brain cancers and advancements in restoring vision through stem cell treatments.
#
# **Technology:** AI continues its rapid evolution, with agentic AI (autonomous agents) poised for significant industrial impact by 2028. Spatial computing, merging physical and digital realms, is projected to reach $1.7 trillion by 2033. Quantum computing advancements are also accelerating, with potential applications in drug discovery and diagnostics within the next 3-5 years.
#
# **Finance:** Blockchain and Decentralized Finance (DeFi) are transforming traditional banking infrastructure, offering enhanced security and efficiency. AI is increasingly used for fraud detection and credit evaluation, with some systems identifying fraud risks months in advance. Digital asset banking and blockchain-based bonds are also gaining traction, with the latter already connecting major financial institutions. These innovations are expected to streamline processes and reduce operational costs across the financial sector in the immediate future.
# TechResearcher > **Key AI/ML Trends: Generative AI, Explainable AI, and Agentic AI**
#
# **Generative AI** is rapidly advancing, moving beyond text to create complex multimedia content like graphics and video. Companies like OpenAI and Google are at the forefront, with applications impacting artistic expression and business workflows. This trend has the potential to revolutionize content creation, design, and even scientific discovery.
#
# **Explainable AI (XAI)** is gaining critical importance as AI models become more complex and are deployed in sensitive sectors like finance and healthcare. The focus is on developing transparent and understandable AI systems, fostering trust and ensuring regulatory compliance. Major tech companies are investing in XAI to address ethical concerns and build reliable AI applications.
#
# **Agentic AI and Autonomous Agents** represent a shift from AI assistants to AI systems capable of handling end-to-end workflows autonomously. The autonomous AI market is projected for significant growth, with companies exploring its application in logistics, autonomous driving, and complex business processes. This trend promises to redefine enterprise efficiency and decision-making.
# FinanceResearcher > Here's your executive briefing on current trends in Tech, Health, and Finance:
#
# **Technology:** Artificial intelligence (AI) continues its rapid democratization, with open-source solutions making advanced capabilities accessible to smaller entities. Agentic AI, capable of autonomous workflows, is emerging as a key development, shifting from assistance to independent action. Gartner highlights AI-native development platforms and AI supercomputing as critical for future innovation.
#
# **Health:** Preventive wellness and personalized healthspan optimization are gaining traction, with consumers seeking proactive solutions. Telehealth adoption is driven by convenience and accessibility, while the aging population and chronic disease management strain health systems.
#
# **Finance:** The financial sector is seeing a rebound in M&A and IPO activity, alongside high demand for investment-grade private credit and asset-backed finance. Generative AI is a significant influence, transforming customer experience and operational efficiency, with a focus on agentic workflows. Digital-first neobanks and evolving payment methods like BNPL are also reshaping the landscape.
# AggregatorAgent > **Executive Summary: Tech, Health, and Finance Briefing**
#
# Across technology, health, and finance, Artificial Intelligence is a pervasive and transformative force, driving innovation and efficiency. In **Technology**, Generative AI is revolutionizing content creation, while Agentic AI is enabling autonomous workflows with significant industrial impact projected by 2028. Explainable AI (XAI) is becoming crucial for trust and compliance in complex systems. **Health** is experiencing groundbreaking advancements through gene therapy and CAR T-cell treatments for inherited diseases and cancers, with potential for vision restoration. Complementary technological advancements like spatial computing and quantum computing are poised to accelerate drug discovery. **Finance** is undergoing a significant digital transformation, with blockchain and Decentralized Finance (DeFi) enhancing security and efficiency. Generative AI is optimizing customer experiences and operations, while agentic workflows are streamlining processes. This synergy of AI-driven automation, advanced medical interventions, and financial system modernization signals a period of rapid progress and disruption.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_48/2323074114.py in <cell line: 1>()
#       1 runner = InMemoryRunner(agent=root_agent)
# ----> 2 response = await runner.run_debug(
#       3     "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
#       4 )
#
# /usr/local/lib/python3.11/dist-packages/google/adk/runners.py in run_debug(self, user_messages, user_id, session_id, run_config, quiet, verbose)
#    1021         print(f'\nUser > {message}')
#    1022
# -> 1023       async for event in self.run_async(
#    1024           user_id=user_id,
#    1025           session_id=session.id,
#
# /usr/local/lib/python3.11/dist-packages/google/adk/runners.py in run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     441
#     442     async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 443       async for event in agen:
#     444         yield event
#     445
#
# /usr/local/lib/python3.11/dist-packages/google/adk/runners.py in _run_with_trace(new_message, invocation_id)
#     425             )
#     426         ) as agen:
# --> 427           async for event in agen:
#     428             yield event
#     429         # Run compaction after all events are yielded from the agent.
#
# /usr/local/lib/python3.11/dist-packages/google/adk/runners.py in _exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     651       # Step 2: Otherwise continue with normal execution
#     652       async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 653         async for event in agen:
#     654           if not event.partial:
#     655             if self._should_append_event(event, is_live_call):
#
# /usr/local/lib/python3.11/dist-packages/google/adk/runners.py in execute(ctx)
#     414         async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     415           async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 416             async for event in agen:
#     417               yield event
#     418
#
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/base_agent.py in run_async(self, parent_context)
#     292
#     293       async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294         async for event in agen:
#     295           yield event
#     296
#
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/sequential_agent.py in _run_async_impl(self, ctx)
#      75
#      76       async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 77         async for event in agen:
#      78           yield event
#      79           if ctx.should_pause_invocation(event):
#
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/base_agent.py in run_async(self, parent_context)
#     292
#     293       async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294         async for event in agen:
#     295           yield event
#     296
#
# /usr/local/lib/python3.11/dist-packages/google/adk/agents/llm_agent.py in _run_async_impl(self, ctx)
#     433     should_pause = False
#     434     async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 435       async for event in agen:
#     436         self.__maybe_save_output_to_state(event)
#     437         yield event
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in run_async(self, invocation_context)
#     354       last_event = None
#     355       async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 356         async for event in agen:
#     357           last_event = event
#     358           yield event
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_one_step_async(self, invocation_context)
#     431         )
#     432     ) as agen:
# --> 433       async for llm_response in agen:
#     434         # Postprocess after calling the LLM.
#     435         async with Aclosing(
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_async(self, invocation_context, llm_request, model_response_event)
#     802
#     803     async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 804       async for event in agen:
#     805         yield event
#     806
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _call_llm_with_tracing()
#     786               )
#     787           ) as agen:
# --> 788             async for llm_response in agen:
#     789               trace_call_llm(
#     790                   invocation_context,
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#     996         yield error_response
#     997       else:
# --> 998         raise model_error
#     999
#    1000   def __get_llm(self, invocation_context: InvocationContext) -> BaseLlm:
#
# /usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py in _run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#     980     try:
#     981       async with Aclosing(response_generator) as agen:
# --> 982         async for response in agen:
#     983           yield response
#     984     except Exception as model_error:
#
# /usr/local/lib/python3.11/dist-packages/google/adk/models/google_llm.py in generate_content_async(self, llm_request, stream)
#     179
#     180     else:
# --> 181       response = await self.api_client.aio.models.generate_content(
#     182           model=llm_request.model,
#     183           contents=llm_request.contents,
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    6854     response = types.GenerateContentResponse()
#    6855     while remaining_remote_calls_afc > 0:
# -> 6856       response = await self._generate_content(
#    6857           model=model, contents=contents, config=parsed_config
#    6858       )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    5665     request_dict = _common.encode_unserializable_types(request_dict)
#    5666
# -> 5667     response = await self._api_client.async_request(
#    5668         'post', path, request_dict, http_options
#    5669     )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in async_request(self, http_method, path, request_dict, http_options)
#    1363     )
#    1364
# -> 1365     result = await self._async_request(
#    1366         http_request=http_request, http_options=http_options, stream=False
#    1367     )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in _async_request(self, http_request, http_options, stream)
#    1308         retry = tenacity.AsyncRetrying(**retry_kwargs)
#    1309         return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1310     return await self._async_retry(  # type: ignore[no-any-return]
#    1311         self._async_request_once, http_request, stream
#    1312     )
#
# /usr/local/lib/python3.11/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     109         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110         while True:
# --> 111             do = await self.iter(retry_state=retry_state)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     151         result = None
#     152         for action in self.iter_state.actions:
# --> 153             result = await action(retry_state)
#     154         return result
#     155
#
# /usr/local/lib/python3.11/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#      97
#      98     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99         return call(*args, **kwargs)
#     100
#     101     return inner
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
# --> 114                     result = await fn(*args, **kwargs)
#     115                 except BaseException:  # noqa: B902
#     116                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in _async_request_once(self, http_request, stream)
#    1253               **self._async_client_session_request_args,
#    1254           )
# -> 1255           await errors.APIError.raise_for_async_response(response)
#    1256           return HttpResponse(response.headers, [await response.text()])
#    1257         except (
#
# /usr/local/lib/python3.11/dist-packages/google/genai/errors.py in raise_for_async_response(cls, response)
#     164
#     165     if 400 <= status_code < 500:
# --> 166       raise ClientError(status_code, response_json, response)
#     167     elif 500 <= status_code < 600:
#     168       raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
